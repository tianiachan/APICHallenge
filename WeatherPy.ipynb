# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#get the api key ready for calls
url = "http://api.openweathermap.org/data/2.5/weather?"

#set count outside of for loop
count = 0
setNum = 1

for city in cities:
    query_url = f"{url}q={city}&appid={weather_api_key}"
    #try to query, if does not work, print error message and move on to next city
    try:
        #set response as lower case so that will match city that is pulled
        response = requests.get(query_url).json()['name'].lower()
        #increment count
        count += 1
        #if within the 50 for a set, print 
        if count <= 50:
            print(f"Processing Record {count} of Set {setNum} | {city}" )
        #otherwise if over 50, resent count and set 
        else:
            count = 0 
            setNum += 1
            print(f"Processing Record {count} of Set {setNum} | {city}" )
    except KeyError:
        print(f"City not found. Skipping ...")
# Out:
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | lewistown
# Processing Record 4 of Set 1 | yumen
# Processing Record 5 of Set 1 | rio gallegos
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | figeac
# City not found. Skipping ...
# Processing Record 9 of Set 1 | prijepolje
# City not found. Skipping ...
# Processing Record 10 of Set 1 | bengkulu
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | darnah
# Processing Record 13 of Set 1 | marsh harbour
# Processing Record 14 of Set 1 | huarmey
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | eyl
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | bluefield
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | touros
# City not found. Skipping ...
# Processing Record 24 of Set 1 | ormara
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | batsfjord
# Processing Record 27 of Set 1 | road town
# City not found. Skipping ...
# Processing Record 28 of Set 1 | kaitangata
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | kaili
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | hofn
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | yar-sale
# Processing Record 36 of Set 1 | chengde
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | tecate
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | nabire
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | nepa nagar
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | torrington
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | kiruna
# Processing Record 49 of Set 1 | oussouye
# Processing Record 50 of Set 1 | half moon bay
# Processing Record 0 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | sur
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | altamont
# Processing Record 4 of Set 2 | obuasi
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | deputatskiy
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | harper
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | ocean city
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | hervey bay
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | lae
# Processing Record 19 of Set 2 | grand gaube
# Processing Record 20 of Set 2 | saint george
# Processing Record 21 of Set 2 | esperance
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | rikitea
# City not found. Skipping ...
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | young
# City not found. Skipping ...
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | sola
# Processing Record 29 of Set 2 | nenzing
# Processing Record 30 of Set 2 | pangnirtung
# Processing Record 31 of Set 2 | san patricio
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | sakassou
# Processing Record 34 of Set 2 | igrim
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | amapa
# City not found. Skipping ...
# Processing Record 38 of Set 2 | xico
# Processing Record 39 of Set 2 | baruta
# Processing Record 40 of Set 2 | sisimiut
# Processing Record 41 of Set 2 | ozinki
# Processing Record 42 of Set 2 | juneau
# Processing Record 43 of Set 2 | santa rosa
# City not found. Skipping ...
# Processing Record 44 of Set 2 | izumo
# Processing Record 45 of Set 2 | santo antonio do monte
# Processing Record 46 of Set 2 | phayakkhaphum phisai
# Processing Record 47 of Set 2 | cabo rojo
# Processing Record 48 of Set 2 | tahoua
# Processing Record 49 of Set 2 | soyo
# Processing Record 50 of Set 2 | airai
# Processing Record 0 of Set 3 | constitucion
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | lata
# Processing Record 4 of Set 3 | vila velha
# Processing Record 5 of Set 3 | nouadhibou
# Processing Record 6 of Set 3 | yarmouth
# Processing Record 7 of Set 3 | shetpe
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | ulladulla
# Processing Record 10 of Set 3 | high level
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | plettenberg bay
# Processing Record 15 of Set 3 | umm lajj
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | banepa
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | pahrump
# Processing Record 20 of Set 3 | batagay-alyta
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | marzuq
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | tigil
# Processing Record 27 of Set 3 | sorland
# Processing Record 28 of Set 3 | lincoln
# Processing Record 29 of Set 3 | caravelas
# Processing Record 30 of Set 3 | inverell
# Processing Record 31 of Set 3 | buguruslan
# Processing Record 32 of Set 3 | maple creek
# Processing Record 33 of Set 3 | dubbo
# Processing Record 34 of Set 3 | hami
# Processing Record 35 of Set 3 | santa isabel do rio negro
# City not found. Skipping ...
# Processing Record 36 of Set 3 | port elizabeth
# City not found. Skipping ...
# Processing Record 37 of Set 3 | taltal
# City not found. Skipping ...
# Processing Record 38 of Set 3 | kamaishi
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | liku
# Processing Record 41 of Set 3 | constantine
# Processing Record 42 of Set 3 | hobyo
# Processing Record 43 of Set 3 | batagay
# Processing Record 44 of Set 3 | awbari
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | luganville
# Processing Record 47 of Set 3 | broken hill
# Processing Record 48 of Set 3 | aldan
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | bjornevatn
# Processing Record 0 of Set 4 | makakilo city
# Processing Record 1 of Set 4 | santiago de cao
# City not found. Skipping ...
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | puerto del rosario
# Processing Record 4 of Set 4 | londrina
# Processing Record 5 of Set 4 | matara
# Processing Record 6 of Set 4 | luderitz
# City not found. Skipping ...
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | bachaquero
# City not found. Skipping ...
# Processing Record 9 of Set 4 | keningau
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | xinan
# Processing Record 12 of Set 4 | ribeira grande
# Processing Record 13 of Set 4 | beasain
# Processing Record 14 of Set 4 | bayangol
# Processing Record 15 of Set 4 | ferme-neuve
# Processing Record 16 of Set 4 | ahipara
# Processing Record 17 of Set 4 | mandali
# Processing Record 18 of Set 4 | kruisfontein
# Processing Record 19 of Set 4 | gornyye klyuchi
# Processing Record 20 of Set 4 | popondetta
# City not found. Skipping ...
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | ilulissat
# Processing Record 23 of Set 4 | tiznit
# Processing Record 24 of Set 4 | mayumba
# Processing Record 25 of Set 4 | yaan
# Processing Record 26 of Set 4 | sao jose da coroa grande
# Processing Record 27 of Set 4 | buchanan
# Processing Record 28 of Set 4 | murfreesboro
# Processing Record 29 of Set 4 | kieta
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | poco verde
# Processing Record 34 of Set 4 | bredasdorp
# Processing Record 35 of Set 4 | adrar
# Processing Record 36 of Set 4 | havoysund
# Processing Record 37 of Set 4 | nyurba
# Processing Record 38 of Set 4 | codrington
# Processing Record 39 of Set 4 | bahia honda
# Processing Record 40 of Set 4 | new norfolk
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | pozo colorado
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | riyadh
# Processing Record 45 of Set 4 | buin
# Processing Record 46 of Set 4 | lingao
# Processing Record 47 of Set 4 | scarborough
# Processing Record 48 of Set 4 | marrakesh
# Processing Record 49 of Set 4 | mabaruma
# Processing Record 50 of Set 4 | serebryanyy bor
# Processing Record 0 of Set 5 | churapcha
# Processing Record 1 of Set 5 | turukhansk
# Processing Record 2 of Set 5 | selfoss
# Processing Record 3 of Set 5 | port shepstone
# Processing Record 4 of Set 5 | havelock
# Processing Record 5 of Set 5 | dayong
# Processing Record 6 of Set 5 | kerrobert
# Processing Record 7 of Set 5 | guangzhou
# Processing Record 8 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 5 | borogontsy
# Processing Record 10 of Set 5 | bereda
# Processing Record 11 of Set 5 | asosa
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | manama
# Processing Record 14 of Set 5 | maraa
# Processing Record 15 of Set 5 | padang
# Processing Record 16 of Set 5 | valparaiso
# Processing Record 17 of Set 5 | ajaccio
# Processing Record 18 of Set 5 | saraland
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | olinda
# Processing Record 21 of Set 5 | naryan-mar
# Processing Record 22 of Set 5 | khatanga
# Processing Record 23 of Set 5 | ixtapa
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | lorengau
# Processing Record 26 of Set 5 | muroto
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | fortuna
# Processing Record 29 of Set 5 | cockburn town
# Processing Record 30 of Set 5 | severo-kurilsk
# Processing Record 31 of Set 5 | kvarkeno
# Processing Record 32 of Set 5 | marawi
# City not found. Skipping ...
# Processing Record 33 of Set 5 | stonehaven
# Processing Record 34 of Set 5 | sainte-rose
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | katherine
# Processing Record 37 of Set 5 | russell
# Processing Record 38 of Set 5 | solano
# Processing Record 39 of Set 5 | balkanabat
# Processing Record 40 of Set 5 | saint anthony
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | benghazi
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | sierra vista
# Processing Record 46 of Set 5 | beckley
# Processing Record 47 of Set 5 | veraval
# Processing Record 48 of Set 5 | santa ines
# Processing Record 49 of Set 5 | sistranda
# Processing Record 50 of Set 5 | erenhot
# Processing Record 0 of Set 6 | aloleng
# Processing Record 1 of Set 6 | faya
# Processing Record 2 of Set 6 | catamarca
# Processing Record 3 of Set 6 | sehithwa
# Processing Record 4 of Set 6 | lesnoy
# Processing Record 5 of Set 6 | bac lieu
# Processing Record 6 of Set 6 | lasa
# Processing Record 7 of Set 6 | arraial do cabo
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 8 of Set 6 | praia
# Processing Record 9 of Set 6 | nioro
# Processing Record 10 of Set 6 | bambous virieux
# Processing Record 11 of Set 6 | ojinaga
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | keffi
# Processing Record 14 of Set 6 | loandjili
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | isangel
# Processing Record 17 of Set 6 | san rafael
# Processing Record 18 of Set 6 | champerico
# Processing Record 19 of Set 6 | hailar
# Processing Record 20 of Set 6 | surab
# Processing Record 21 of Set 6 | magnitka
# Processing Record 22 of Set 6 | uberlandia
# Processing Record 23 of Set 6 | rudbar
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | seoul
# Processing Record 26 of Set 6 | asau
# Processing Record 27 of Set 6 | tecpatan
# Processing Record 28 of Set 6 | tura
# Processing Record 29 of Set 6 | nizhniy tsasuchey
# Processing Record 30 of Set 6 | te anau
# Processing Record 31 of Set 6 | kaseda
# City not found. Skipping ...
# Processing Record 32 of Set 6 | leningradskiy
# City not found. Skipping ...
# Processing Record 33 of Set 6 | san vicente de canete
# Processing Record 34 of Set 6 | atar
# Processing Record 35 of Set 6 | xining
# Processing Record 36 of Set 6 | port-gentil
# City not found. Skipping ...
# Processing Record 37 of Set 6 | kyaikkami
# Processing Record 38 of Set 6 | balad
# Processing Record 39 of Set 6 | auki
# Processing Record 40 of Set 6 | birjand
# Processing Record 41 of Set 6 | salvador
# Processing Record 42 of Set 6 | coihaique
# Processing Record 43 of Set 6 | castro
# Processing Record 44 of Set 6 | anuradhapura
# Processing Record 45 of Set 6 | komsomolskiy
# Processing Record 46 of Set 6 | avila
# Processing Record 47 of Set 6 | kashan
# Processing Record 48 of Set 6 | usogorsk
# Processing Record 49 of Set 6 | ikwiriri
# Processing Record 50 of Set 6 | havre-saint-pierre
# Processing Record 0 of Set 7 | acajutla
# Processing Record 1 of Set 7 | feijo
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | shaunavon
# Processing Record 4 of Set 7 | astana
# Processing Record 5 of Set 7 | khorixas
# Processing Record 6 of Set 7 | fort nelson
# Processing Record 7 of Set 7 | alugan
# City not found. Skipping ...
# Processing Record 8 of Set 7 | kalmunai
# Processing Record 9 of Set 7 | port said
# Processing Record 10 of Set 7 | pangody
# Processing Record 11 of Set 7 | bronnoysund
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | tingo maria
# Processing Record 14 of Set 7 | nanortalik
# City not found. Skipping ...
# Processing Record 15 of Set 7 | goderich
# Processing Record 16 of Set 7 | dublin
# Processing Record 17 of Set 7 | sao paulo de olivenca
# Processing Record 18 of Set 7 | ola
# Processing Record 19 of Set 7 | okhotsk
# Processing Record 20 of Set 7 | ulaanbaatar
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | kailua
# Processing Record 23 of Set 7 | hall
# Processing Record 24 of Set 7 | caraballeda
# Processing Record 25 of Set 7 | svetlyy
# Processing Record 26 of Set 7 | namatanai
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | fomboni
# Processing Record 29 of Set 7 | andenes
# Processing Record 30 of Set 7 | bunia
# Processing Record 31 of Set 7 | yulara
# Processing Record 32 of Set 7 | wuning
# Processing Record 33 of Set 7 | musoma
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | saldanha
# Processing Record 36 of Set 7 | sohag
# Processing Record 37 of Set 7 | baoma
# Processing Record 38 of Set 7 | whitehorse
# Processing Record 39 of Set 7 | kalanguy
# Processing Record 40 of Set 7 | usinsk
# Processing Record 41 of Set 7 | luena
# Processing Record 42 of Set 7 | hasaki
# Processing Record 43 of Set 7 | gagra
# Processing Record 44 of Set 7 | beidao
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | malindi
# Processing Record 47 of Set 7 | troitsko-pechorsk
# Processing Record 48 of Set 7 | majadahonda
# Processing Record 49 of Set 7 | valdivia
# Processing Record 50 of Set 7 | nhulunbuy
# Processing Record 0 of Set 8 | berlevag
# Processing Record 1 of Set 8 | iqaluit
# Processing Record 2 of Set 8 | murray bridge
# City not found. Skipping ...
# Processing Record 3 of Set 8 | progreso
# Processing Record 4 of Set 8 | kahului
# Processing Record 5 of Set 8 | bodh gaya
# Processing Record 6 of Set 8 | norman wells
# Processing Record 7 of Set 8 | beira
# Processing Record 8 of Set 8 | urubicha
# Processing Record 9 of Set 8 | shiyan
# Processing Record 10 of Set 8 | beringovskiy
# Processing Record 11 of Set 8 | yerbogachen
# Processing Record 12 of Set 8 | benguela
# Processing Record 13 of Set 8 | rantepao
# Processing Record 14 of Set 8 | lazaro cardenas
# Processing Record 15 of Set 8 | townsville
# Processing Record 16 of Set 8 | olsztyn
# Processing Record 17 of Set 8 | le vauclin
# Processing Record 18 of Set 8 | londoko
# Processing Record 19 of Set 8 | bosaso
# Processing Record 20 of Set 8 | san quintin
# Processing Record 21 of Set 8 | manzhouli
# Processing Record 22 of Set 8 | lagoa
# Processing Record 23 of Set 8 | udachnyy
# Processing Record 24 of Set 8 | abha
# Processing Record 25 of Set 8 | bauta
# Processing Record 26 of Set 8 | meadow lake
# Processing Record 27 of Set 8 | plastun
# Processing Record 28 of Set 8 | killarney
# Processing Record 29 of Set 8 | flinders
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | vryheid
# City not found. Skipping ...
# Processing Record 32 of Set 8 | gazojak
# Processing Record 33 of Set 8 | yabelo
# City not found. Skipping ...
# Processing Record 34 of Set 8 | rio grande
# Processing Record 35 of Set 8 | coquimbo
# Processing Record 36 of Set 8 | kenai
# Processing Record 37 of Set 8 | san juan
# Processing Record 38 of Set 8 | moree
# Processing Record 39 of Set 8 | aripuana
# Processing Record 40 of Set 8 | saravan
# City not found. Skipping ...
# Processing Record 41 of Set 8 | sao felix do xingu
# Processing Record 42 of Set 8 | orlik
# Processing Record 43 of Set 8 | vadu moldovei
# Processing Record 44 of Set 8 | gazanjyk
# Processing Record 45 of Set 8 | saint-joseph
# Processing Record 46 of Set 8 | nicoya
# City not found. Skipping ...
# Processing Record 47 of Set 8 | lagos
# Processing Record 48 of Set 8 | chokurdakh
# Processing Record 49 of Set 8 | alekseyevsk
# Processing Record 50 of Set 8 | klyuchevskiy
# Processing Record 0 of Set 9 | waipawa
# Processing Record 1 of Set 9 | mount gambier
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 2 of Set 9 | gamba
# Processing Record 3 of Set 9 | gao
# Processing Record 4 of Set 9 | rafaela
# City not found. Skipping ...
# Processing Record 5 of Set 9 | sawakin
# Processing Record 6 of Set 9 | onguday
# Processing Record 7 of Set 9 | marsa matruh
# Processing Record 8 of Set 9 | cap malheureux
# Processing Record 9 of Set 9 | sechura
# Processing Record 10 of Set 9 | tautira
# Processing Record 11 of Set 9 | svetlaya
# Processing Record 12 of Set 9 | wageningen
# Processing Record 13 of Set 9 | mokhsogollokh
# Processing Record 14 of Set 9 | erzin
# Processing Record 15 of Set 9 | aleksandrov gay
# City not found. Skipping ...
# Processing Record 16 of Set 9 | fort pierce
# Processing Record 17 of Set 9 | lixourion
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | camargo
# Processing Record 20 of Set 9 | voi
# Processing Record 21 of Set 9 | darovskoy
# Processing Record 22 of Set 9 | chokwe
# Processing Record 23 of Set 9 | el rosal
# Processing Record 24 of Set 9 | corozal
# Processing Record 25 of Set 9 | derby
# City not found. Skipping ...
# Processing Record 26 of Set 9 | ambanja
# Processing Record 27 of Set 9 | khani
# Processing Record 28 of Set 9 | krasnovishersk
# Processing Record 29 of Set 9 | gouyave
# City not found. Skipping ...
# Processing Record 30 of Set 9 | pasni
# Processing Record 31 of Set 9 | narrabri
# Processing Record 32 of Set 9 | mazatlan
# Processing Record 33 of Set 9 | shizunai
# City not found. Skipping ...
# Processing Record 34 of Set 9 | fairbanks
# City not found. Skipping ...
# Processing Record 35 of Set 9 | atambua
# Processing Record 36 of Set 9 | juruti
# Processing Record 37 of Set 9 | aras
# Processing Record 38 of Set 9 | bontang
# Processing Record 39 of Set 9 | katsuura
# Processing Record 40 of Set 9 | issenye
# City not found. Skipping ...
# Processing Record 41 of Set 9 | salisbury
# Processing Record 42 of Set 9 | ahuimanu
# Processing Record 43 of Set 9 | eskilstuna
# Processing Record 44 of Set 9 | galesong
# Processing Record 45 of Set 9 | nanakuli
# Processing Record 46 of Set 9 | belmonte
# Processing Record 47 of Set 9 | ichhawar
# Processing Record 48 of Set 9 | tinaquillo
# Processing Record 49 of Set 9 | lensk
# Processing Record 50 of Set 9 | shizuishan
# Processing Record 0 of Set 10 | lulea
# Processing Record 1 of Set 10 | labuhan
# Processing Record 2 of Set 10 | talas
# Processing Record 3 of Set 10 | taoudenni
# Processing Record 4 of Set 10 | cabatuan
# Processing Record 5 of Set 10 | dunedin
# Processing Record 6 of Set 10 | mae sai
# Processing Record 7 of Set 10 | dubovskoye
# Processing Record 8 of Set 10 | smidovich
# Processing Record 9 of Set 10 | uvalde
# Processing Record 10 of Set 10 | egvekinot
# Processing Record 11 of Set 10 | iguape
# Processing Record 12 of Set 10 | lichinga
# Processing Record 13 of Set 10 | yamada
# Processing Record 14 of Set 10 | miri
# Processing Record 15 of Set 10 | mahanje
# Processing Record 16 of Set 10 | chernyshevskiy
# Processing Record 17 of Set 10 | tres passos
# Processing Record 18 of Set 10 | inuvik
# Processing Record 19 of Set 10 | bud
# Processing Record 20 of Set 10 | bagotville
# Processing Record 21 of Set 10 | gambo
# Processing Record 22 of Set 10 | boyabat
# Processing Record 23 of Set 10 | port hedland
# Processing Record 24 of Set 10 | samarai
# City not found. Skipping ...
# Processing Record 25 of Set 10 | somers point
# Processing Record 26 of Set 10 | port blair
# Processing Record 27 of Set 10 | davila
# Processing Record 28 of Set 10 | srednekolymsk
# Processing Record 29 of Set 10 | inirida
# Processing Record 30 of Set 10 | daulatpur
# Processing Record 31 of Set 10 | sovetskiy
# Processing Record 32 of Set 10 | tarauaca
# City not found. Skipping ...
# Processing Record 33 of Set 10 | maragogi
# Processing Record 34 of Set 10 | soma
# Processing Record 35 of Set 10 | hamilton
# Processing Record 36 of Set 10 | guangshui
# Processing Record 37 of Set 10 | najran
# Processing Record 38 of Set 10 | kannur
# Processing Record 39 of Set 10 | scituate
# City not found. Skipping ...
# Processing Record 40 of Set 10 | dharchula
# Processing Record 41 of Set 10 | kokkola
# Processing Record 42 of Set 10 | hay river
# Processing Record 43 of Set 10 | myitkyina
# Processing Record 44 of Set 10 | kichera
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | timra
# Processing Record 47 of Set 10 | saint-pierre
# Processing Record 48 of Set 10 | ancud
# Processing Record 49 of Set 10 | malanje
# Processing Record 50 of Set 10 | meulaboh
# City not found. Skipping ...
# Processing Record 0 of Set 11 | santa cruz
# Processing Record 1 of Set 11 | akureyri
# Processing Record 2 of Set 11 | chadiza
# Processing Record 3 of Set 11 | kuito
# Processing Record 4 of Set 11 | karratha
# City not found. Skipping ...
# Processing Record 5 of Set 11 | brawley
# Processing Record 6 of Set 11 | sao joao da barra
# Processing Record 7 of Set 11 | enshi
# Processing Record 8 of Set 11 | kajaani
# Processing Record 9 of Set 11 | el alto
# Processing Record 10 of Set 11 | husavik
# Processing Record 11 of Set 11 | floresta
# City not found. Skipping ...
# Processing Record 12 of Set 11 | mareeba
# Processing Record 13 of Set 11 | sitamarhi
# Processing Record 14 of Set 11 | senanga
# Processing Record 15 of Set 11 | bonavista
# Processing Record 16 of Set 11 | kirakira
# Processing Record 17 of Set 11 | cooma
# Processing Record 18 of Set 11 | jaciara
# Processing Record 19 of Set 11 | gambela
# City not found. Skipping ...
# City not found. Skipping ...
# Processing Record 20 of Set 11 | lavrentiya
# Processing Record 21 of Set 11 | mount isa
# Processing Record 22 of Set 11 | harnosand
# Processing Record 23 of Set 11 | kudahuvadhoo
# Processing Record 24 of Set 11 | zeya
# Processing Record 25 of Set 11 | poykovskiy
# City not found. Skipping ...
# Processing Record 26 of Set 11 | pijijiapan
# Processing Record 27 of Set 11 | roma
# Processing Record 28 of Set 11 | changji
# Processing Record 29 of Set 11 | kokopo
# Processing Record 30 of Set 11 | ust-tsilma
# Processing Record 31 of Set 11 | iracoubo
# Processing Record 32 of Set 11 | tazovskiy
# Processing Record 33 of Set 11 | luancheng
# Processing Record 34 of Set 11 | manicore
# Processing Record 35 of Set 11 | kropotkin

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create lists to hold city data
name, iD, cloud, country, date, humidity, lat, lngtd, maxTemp, wind = ([] for i in range(10))

#get information and append
for city in cities:
    name.append(city)
    print(city)
    
#     response = requests.get(query_url).json() just query once and then pull data from the query
    City_ID = requests.get(query_url).json()['id']
    iD.append(City_ID)
    print(City_ID)
    
    Cloudiness = requests.get(query_url).json()['weather'][0]['description']
    cloud.append(Cloudiness)
    print(Cloudiness)
    
    Country = requests.get(query_url).json()['sys']['country']
    country.append(Country)
    print(Country)
    
    Date = requests.get(query_url).json()['dt']
    date.append(Date)
    print(Date)
    
    Humidity = requests.get(query_url).json()['main']['humidity']
    humidity.append(Humidity)
    print(Humidity)
    
    Lat = requests.get(query_url).json()['coord']['lat']
    lat.append(Lat)
    print(Lat)
    
    Lng = requests.get(query_url).json()['coord']['lon']
    lngtd.append(Lng)
    print(Lng)
    
    MaxTemp = requests.get(query_url).json()['main']['temp_max']
    maxTemp.append(MaxTemp)
    print(MaxTemp)
    
    WindSpeed = requests.get(query_url).json()['wind']['speed']
    wind.append(WindSpeed)
    print(WindSpeed)

#compile all lists into a dictionary
city_weather_Dict = {
    "City_ID" : iD,
    "City" : name,
    "Cloudiness" : cloud,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lng" : lngtd,
    "Max Team" : maxTemp,
    "Wind Speed" : wind
}
#put information into a dataframe
city_weatherDF = pd.DataFrame(city_weather_Dict)
city_weatherDF.head()
# Out:
# gizo
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6d4d0d3c848a> in <module>
#       7     print(city)
#       8
# ----> 9     City_ID = requests.get(query_url).json()['id']
#      10     iD.append(City_ID)
#      11     print(City_ID)
#
# KeyError: 'id'

# %%
#put into csv
city_weatherDF.to_csv("cities.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
